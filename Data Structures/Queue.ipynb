# %% [markdown]
# **Using list as a queue**

# %%
wmt_stock_price_queue = []

# %%
wmt_stock_price_queue.insert(0,131.10)
wmt_stock_price_queue.insert(0,132.12)
wmt_stock_price_queue.insert(0,133)

# %%
wmt_stock_price_queue
# Out:
# [133, 132.12, 131.1]

# %%
wmt_stock_price_queue.pop()
# Out:
# 131.1

# %%
wmt_stock_price_queue.pop()
# Out:
# 132.12

# %%
wmt_stock_price_queue.pop()  # now is empty
# Out:
# 133

# %% [markdown]
# **Using collections.deque as a queue**

# %%
from collections import deque
q = deque()

# %%
q.appendleft(5)
q.appendleft(7)
q.appendleft(9)

# %%
q.pop()
# Out:
# 5

# %%
q.pop()
# Out:
# 7

# %%
q.pop()
# Out:
# 9

# %% [markdown]
# **Implement queue class using collections.deque**

# %%
from collections import deque

class Queue:
    def __init__(self):
        self.buffer = deque()
    
    def enqueue(self,val):
        self.buffer.appendleft(val)
        
    def dequeue(self):
        return self.buffer.pop()
    
    def is_empty(self):
        return len(self.buffer)==0
    
    def size(self):
        return len(self.buffer)

# %%
pq = Queue()

pq.enqueue({
    'company': 'Wall Mart',
    'timestamp': '15 apr, 11.01 AM',
    'price': 131.10
})
pq.enqueue({
    'company': 'Wall Mart',
    'timestamp': '15 apr, 11.02 AM',
    'price': 132
})
pq.enqueue({
    'company': 'Wall Mart',
    'timestamp': '15 apr, 11.03 AM',
    'price': 133
})

# %%
pq.size()
# Out:
# 3

# %%
pq.dequeue()
# Out:
# {'company': 'Wall Mart', 'price': 131.1, 'timestamp': '15 apr, 11.01 AM'}

# %%
pq.dequeue()
# Out:
# {'company': 'Wall Mart', 'price': 132, 'timestamp': '15 apr, 11.02 AM'}

# %%
pq.dequeue()
# Out:
# {'company': 'Wall Mart', 'price': 133, 'timestamp': '15 apr, 11.03 AM'}
