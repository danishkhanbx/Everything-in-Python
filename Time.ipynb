# %%
import time as t

# %%
t.localtime()
# Out:
# time.struct_time(tm_year=2022, tm_mon=7, tm_mday=7, tm_hour=8, tm_min=13, tm_sec=18, tm_wday=3, tm_yday=188, tm_isdst=0)

# %% [markdown]
# Printing the exact time for transaction:

# %%
time_now = t.localtime()

# %%
print('Transaction completed at',str(time_now.tm_hour)+'h '+str(time_now.tm_min)+'m')
# Out:
# Transaction completed at 8h 14m

# %% [markdown]
# Time past since the Apoc(1970).

# %%
t.time()
# Out:
# 1657181746.4598804

# %% [markdown]
# Timestamp for delivery in 7 days.

# %%
time_now = t.time()
delivery_time = time_now + (86400 * 7)
t.localtime(delivery_time)
# Out:
# time.struct_time(tm_year=2022, tm_mon=7, tm_mday=14, tm_hour=8, tm_min=19, tm_sec=13, tm_wday=3, tm_yday=195, tm_isdst=0)

# %%
t.sleep(5)
