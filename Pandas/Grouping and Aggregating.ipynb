# %%
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('/content/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
#               CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1            European Euro            EUR   Microsoft SQL Server
# 2           Pound sterling            GBP                    NaN
# 3                      NaN            NaN                    NaN
# 4             Albanian lek            ALL                    NaN
# 5                      NaN            NaN       MySQL;PostgreSQL
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                       MySQL;PostgreSQL;Redis;SQLite
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
# 4                                NaN                       NaN
# 5                    Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                         PlatformWorkedWith                      PurchaseWhat  \
# Respondent
# 1                                  Windows                               NaN
# 2                                      iOS     I have little or no influence
# 3                                      NaN                               NaN
# 4                                      NaN  I have a great deal of influence
# 5           AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                           Sexuality SOAccount           SOComm  \
# Respondent
# 1           Straight / Heterosexual        No   No, not at all
# 2                               NaN       Yes  Yes, definitely
# 3                               NaN       Yes    Yes, somewhat
# 4           Straight / Heterosexual       Yes  Yes, definitely
# 5           Straight / Heterosexual       Yes    Yes, somewhat
#
#                                      SOPartFreq  \
# Respondent
# 1                                           NaN
# 2           Less than once per month or monthly
# 3               A few times per month or weekly
# 4               A few times per month or weekly
# 5           Less than once per month or monthly
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# 5            Django;Ruby on Rails         Ruby on Rails
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN
# 4                     4
# 5                     8

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8     116000.0
# 9          NaN
# 10     32315.0
# 11     40070.0
# 12     14268.0
# 13     38916.0
# 14     66000.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 83000.0

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Age                 31.0
# CompTotal        88000.0
# ConvertedComp    83000.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                Age     CompTotal  ConvertedComp  WorkWeekHrs
# count  3251.000000  2.584000e+03   2.575000e+03  2934.000000
# mean     32.829991  3.869969e+45   1.504147e+05    40.948023
# std      10.556627  1.967224e+47   3.053648e+05    12.838553
# min      11.000000  0.000000e+00   0.000000e+00     2.000000
# 25%      25.000000  5.000000e+04   4.864400e+04    40.000000
# 50%      31.000000  8.800000e+04   8.300000e+04    40.000000
# 75%      38.000000  1.310000e+05   1.300000e+05    42.000000
# max      99.000000  1.000000e+49   2.000000e+06   375.000000

# %%
df['ConvertedComp'].count()
# Out:
# 2575

# %%
df['Hobbyist']
# Out:
# Respondent
# 1       Yes
# 2        No
# 3       Yes
# 4       Yes
# 5       Yes
#        ...
# 3714    Yes
# 3715    Yes
# 3716    Yes
# 3717     No
# 3718    Yes
# Name: Hobbyist, Length: 3704, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    2932
# No      772
# Name: Hobbyist, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States         1889
# Canada                 342
# United Kingdom         190
# Germany                152
# India                  125
#                       ...
# Ethiopia                 1
# Honduras                 1
# Kyrgyzstan               1
# Panama                   1
# Hong Kong (S.A.R.)       1
# Name: Country, Length: 104, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 3332                I am a developer by profession      Yes   NaN         19
# 3556                I am a developer by profession      Yes  35.0         12
# 3587        I am a student who is learning to code      Yes  20.0         15
# 3600                I am a developer by profession      Yes  33.0         34
# 3650                I am a developer by profession      Yes  25.0         18
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58              NaN         NaN            NaN   India          Indian rupee
# 63              NaN         NaN            NaN   India                   NaN
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
# ...             ...         ...            ...     ...                   ...
# 3332        Monthly  42000000.0      1000000.0   India          Indian rupee
# 3556            NaN         NaN            NaN   India          Indian rupee
# 3587            NaN         NaN            NaN   India                   NaN
# 3600        Monthly    450000.0        75396.0   India          Indian rupee
# 3650        Monthly    100000.0        16752.0   India          Indian rupee
#
#            CurrencySymbol                             DatabaseDesireNextYear  \
# Respondent
# 7                     USD                                                NaN
# 22                    INR                                                NaN
# 58                    INR                               Microsoft SQL Server
# 63                    NaN                                           DynamoDB
# 149                   INR                         Cassandra;MySQL;PostgreSQL
# ...                   ...                                                ...
# 3332                  INR  Cassandra;DynamoDB;Elasticsearch;MongoDB;MySQL...
# 3556                  INR                               MongoDB;MySQL;SQLite
# 3587                  NaN       Firebase;Microsoft SQL Server;MongoDB;Oracle
# 3600                  INR                                            MongoDB
# 3650                  INR                          DynamoDB;PostgreSQL;Redis
#
#                                            DatabaseWorkedWith  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                       Microsoft SQL Server
# 63                                     Firebase;MongoDB;MySQL
# 149                                          MySQL;PostgreSQL
# ...                                                       ...
# 3332                           MongoDB;MySQL;PostgreSQL;Redis
# 3556         Microsoft SQL Server;MongoDB;MySQL;Oracle;SQLite
# 3587                                                    MySQL
# 3600         DynamoDB;Elasticsearch;Firebase;PostgreSQL;Redis
# 3650        DynamoDB;Elasticsearch;Microsoft SQL Server;Mo...
#
#                                                       DevType  \
# Respondent
# 7           Developer, back-end;Developer, front-end;Devel...
# 22                       Developer, full-stack;Engineer, data
# 58                                        Developer, back-end
# 63          Designer;Developer, back-end;Developer, front-...
# 149         Developer, back-end;Developer, QA or test;DevO...
# ...                                                       ...
# 3332                                      Developer, back-end
# 3556        Designer;Developer, back-end;Developer, deskto...
# 3587                                                      NaN
# 3600        Database administrator;Developer, back-end;Dev...
# 3650        Developer, back-end;Developer, front-end;Devel...
#
#                                                       EdLevel  \
# Respondent
# 7                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58                                                        NaN
# 63          Secondary school (e.g. American high school, G...
# 149              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 3332             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3556        Some college/university study without earning ...
# 3587        Secondary school (e.g. American high school, G...
# 3600             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3650             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment    Ethnicity  \
# Respondent
# 7                                          Employed full-time          NaN
# 22                                         Employed full-time          NaN
# 58          Independent contractor, freelancer, or self-em...  South Asian
# 63                         Not employed, but looking for work  South Asian
# 149                                        Employed full-time   East Asian
# ...                                                       ...          ...
# 3332                                       Employed full-time          NaN
# 3556        Independent contractor, freelancer, or self-em...  South Asian
# 3587                                                  Student          NaN
# 3600                                       Employed full-time  South Asian
# 3650                                       Employed full-time  South Asian
#
#            Gender                                         JobFactors  \
# Respondent
# 7             NaN                                                NaN
# 22            Man                                                NaN
# 58            NaN                                Family friendliness
# 63            Man  Flex time or a flexible schedule;How widely us...
# 149           Man  Languages, frameworks, and other technologies ...
# ...           ...                                                ...
# 3332          NaN  Flex time or a flexible schedule;Specific depa...
# 3556          Man  Diversity of the company or organization;Langu...
# 3587          Man  Industry that I’d be working in;Languages, fra...
# 3600          Man  Industry that I’d be working in;Financial perf...
# 3650          Man  Languages, frameworks, and other technologies ...
#
#                                         JobSat  \
# Respondent
# 7                               Very satisfied
# 22                       Slightly dissatisfied
# 58                              Very satisfied
# 63                                         NaN
# 149                             Very satisfied
# ...                                        ...
# 3332        Neither satisfied nor dissatisfied
# 3556        Neither satisfied nor dissatisfied
# 3587                                       NaN
# 3600                        Slightly satisfied
# 3650                        Slightly satisfied
#
#                                                       JobSeek  \
# Respondent
# 7           I’m not actively looking, but I am open to new...
# 22                            I am actively looking for a job
# 58               I am not interested in new job opportunities
# 63                            I am actively looking for a job
# 149              I am not interested in new job opportunities
# ...                                                       ...
# 3332        I’m not actively looking, but I am open to new...
# 3556        I’m not actively looking, but I am open to new...
# 3587        I’m not actively looking, but I am open to new...
# 3600        I’m not actively looking, but I am open to new...
# 3650                          I am actively looking for a job
#
#                                        LanguageDesireNextYear  \
# Respondent
# 7                                             C#;HTML/CSS;PHP
# 22                                     Java;JavaScript;Python
# 58                               C#;JavaScript;SQL;TypeScript
# 63                                       Go;Kotlin;TypeScript
# 149               Bash/Shell/PowerShell;C;C++;Java;Perl;Scala
# ...                                                       ...
# 3332                      Go;Java;JavaScript;Python;Scala;SQL
# 3556        C#;Dart;Java;JavaScript;Kotlin;Python;SQL;Swif...
# 3587           Bash/Shell/PowerShell;C#;Python;TypeScript;VBA
# 3600                                                      NaN
# 3650        Java;JavaScript;Kotlin;Objective-C;Python;SQL;...
#
#                                            LanguageWorkedWith  \
# Respondent
# 7                                             C#;HTML/CSS;PHP
# 22                                                Java;Python
# 58                               C#;JavaScript;SQL;TypeScript
# 63                      C;C++;HTML/CSS;Java;JavaScript;Python
# 149                            Bash/Shell/PowerShell;C++;Perl
# ...                                                       ...
# 3332                                 Go;Java;Python;Scala;SQL
# 3556        Assembly;C;C#;C++;Java;JavaScript;Kotlin;Objec...
# 3587                       C;C++;HTML/CSS;Java;JavaScript;SQL
# 3600        Bash/Shell/PowerShell;Go;Java;JavaScript;Kotli...
# 3650                           Java;JavaScript;SQL;TypeScript
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                     .NET;.NET Core;Node.js
# 63                    Flutter;Node.js;React Native;TensorFlow
# 149                                              Apache Spark
# ...                                                       ...
# 3332          Apache Spark;Node.js;Pandas;TensorFlow;Teraform
# 3556        .NET;Apache Spark;Cordova;Flutter;Hadoop;Node....
# 3587                 .NET;.NET Core;Node.js;Pandas;TensorFlow
# 3600                 Ansible;React Native;TensorFlow;Teraform
# 3650        Flutter;Node.js;React Native;TensorFlow;Torch/...
#
#                                         MiscTechWorkedWith  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58                                  .NET;.NET Core;Node.js
# 63                                                     NaN
# 149                                                    NaN
# ...                                                    ...
# 3332        Ansible;Apache Spark;Node.js;Pandas;TensorFlow
# 3556                     .NET;Flutter;Node.js;React Native
# 3587                                                   NaN
# 3600                                               Ansible
# 3650                                       Ansible;Node.js
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                   Stack Overflow for Teams
# 63                        Confluence;Stack Overflow for Teams
# 149         Confluence;Jira;Github;Gitlab;Google Suite (Do...
# ...                                                       ...
# 3332                      Github;Slack;Microsoft Azure;Trello
# 3556                                            Github;Gitlab
# 3587                                 Stack Overflow for Teams
# 3600                    Slack;Microsoft Teams;Microsoft Azure
# 3650        Jira;Github;Gitlab;Slack;Google Suite (Docs, M...
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 7                                                         NaN       Yes
# 22                                                        NaN  Not sure
# 58                                   Stack Overflow for Teams       Yes
# 63          Github;Facebook Workplace;Slack;Microsoft Team...       NaN
# 149         Confluence;Jira;Github;Google Suite (Docs, Mee...  Not sure
# ...                                                       ...       ...
# 3332        Confluence;Jira;Github;Slack;Microsoft Azure;T...        No
# 3556                                                   Github       Yes
# 3587                                                   Github       NaN
# 3600                                       Jira;Github;Gitlab       Yes
# 3650        Confluence;Jira;Github;Gitlab;Slack;Google Sui...        No
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 7           Extremely important                      Very important
# 22                          NaN                      Very important
# 58          Extremely important                      Very important
# 63                          NaN                                 NaN
# 149                     Neutral                Critically important
# ...                         ...                                 ...
# 3332                    Neutral                    Fairly important
# 3556         Somewhat important                Critically important
# 3587                        NaN                                 NaN
# 3600        Extremely important  Not at all important/not necessary
# 3650        Extremely important                  Somewhat important
#
#                                                    NEWJobHunt  \
# Respondent
# 7           Better compensation;Growth or leadership oppor...
# 22          Better compensation;Better work/life balance;W...
# 58                                                        NaN
# 63                                                        NaN
# 149         Just because;Curious about other opportunities...
# ...                                                       ...
# 3332        Just because;Better compensation;Trouble with ...
# 3556        Better compensation;Wanting to work with new t...
# 3587                                                      NaN
# 3600        Just because;Having a bad day (or week or mont...
# 3650        Wanting to share accomplishments with a wider ...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 7           Read company media, such as employee blogs or ...
# 22          Company reviews from third party sites (e.g. G...
# 58                                                        NaN
# 63                                                        NaN
# 149         Read company media, such as employee blogs or ...
# ...                                                       ...
# 3332        Company reviews from third party sites (e.g. G...
# 3556        Read company media, such as employee blogs or ...
# 3587                                                      NaN
# 3600        Read company media, such as employee blogs or ...
# 3650        Read company media, such as employee blogs or ...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 7               Every few months         Yes                           Yes
# 22              Every few months          No                           Yes
# 58          Once every few years         NaN                           Yes
# 63                   Once a year         Yes                           NaN
# 149                  Once a year    Not sure  Onboarding? What onboarding?
# ...                          ...         ...                           ...
# 3332            Every few months          No                            No
# 3556            Every few months         Yes                           Yes
# 3587            Every few months          No                           NaN
# 3600            Every few months          No                            No
# 3650                 Once a year          No  Onboarding? What onboarding?
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 7                     No  Sometimes: 1-2 days per month but less than we...
# 22                    No                   Often: 1-2 days per week or more
# 58                    No                   Often: 1-2 days per week or more
# 63                    No                                                NaN
# 149                   No  Sometimes: 1-2 days per month but less than we...
# ...                  ...                                                ...
# 3332                 Yes  Sometimes: 1-2 days per month but less than we...
# 3556                  No                   Often: 1-2 days per week or more
# 3587                  No                                                NaN
# 3600                  No                   Often: 1-2 days per week or more
# 3650                 Yes                   Often: 1-2 days per week or more
#
#                                           NEWPurchaseResearch  \
# Respondent
# 7           Start a free trial;Ask developers I know/work ...
# 22                                                        NaN
# 58                            Ask developers I know/work with
# 63          Start a free trial;Ask developers I know/work ...
# 149                                                       NaN
# ...                                                       ...
# 3332        Start a free trial;Ask developers I know/work ...
# 3556        Start a free trial;Ask developers I know/work ...
# 3587        Start a free trial;Ask developers I know/work ...
# 3600        Start a free trial;Research companies that hav...
# 3650        Start a free trial;Visit developer communities...
#
#                 NEWPurpleLink  \
# Respondent
# 7                         NaN
# 22                        NaN
# 58          Hello, old friend
# 63          Hello, old friend
# 149               Indifferent
# ...                       ...
# 3332              Indifferent
# 3556                   Amused
# 3587                   Amused
# 3600                   Amused
# 3650        Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 7            Stack Overflow (public Q&A for anyone who codes)
# 22          Stack Overflow (public Q&A for anyone who code...
# 58          Stack Overflow (public Q&A for anyone who code...
# 63          Stack Overflow (public Q&A for anyone who code...
# 149          Stack Overflow (public Q&A for anyone who codes)
# ...                                                       ...
# 3332        Stack Overflow (public Q&A for anyone who code...
# 3556        Stack Overflow (public Q&A for anyone who code...
# 3587        Stack Overflow (public Q&A for anyone who code...
# 3600         Stack Overflow (public Q&A for anyone who codes)
# 3650        Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 7                                                         NaN      Windows
# 22                                                        NaN      Windows
# 58          Call a coworker or friend;Visit Stack Overflow...      Windows
# 63          Visit Stack Overflow;Go for a walk or other ph...      Windows
# 149         Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# ...                                                       ...          ...
# 3332        Call a coworker or friend;Visit Stack Overflow...        MacOS
# 3556                                     Visit Stack Overflow      Windows
# 3587        Call a coworker or friend;Visit Stack Overflow...      Windows
# 3600        Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 3650        Call a coworker or friend;Visit Stack Overflow...        MacOS
#
#                                                       OrgSize  \
# Respondent
# 7                                          20 to 99 employees
# 22                                       500 to 999 employees
# 58                                                        NaN
# 63                                                        NaN
# 149                                      500 to 999 employees
# ...                                                       ...
# 3332                                 10,000 or more employees
# 3556        Just me - I am a freelancer, sole proprietor, ...
# 3587                                                      NaN
# 3600                                     100 to 499 employees
# 3650                                       10 to 19 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                                        NaN
# 63                                      AWS;Docker;Heroku;iOS
# 149                               Google Cloud Platform;Linux
# ...                                                       ...
# 3332        AWS;Docker;Google Cloud Platform;Heroku;Kubern...
# 3556        Android;AWS;Google Cloud Platform;iOS;MacOS;Wi...
# 3587                                    Arduino;AWS;WordPress
# 3600                                    Google Cloud Platform
# 3650        Android;AWS;Docker;Google Cloud Platform;iOS;M...
#
#                                            PlatformWorkedWith  \
# Respondent
# 7                                                         NaN
# 22                                                        NaN
# 58                                                        NaN
# 63          Android;Arduino;Google Cloud Platform;Raspberr...
# 149                                                     Linux
# ...                                                       ...
# 3332        AWS;Docker;Kubernetes;Linux;MacOS;Microsoft Azure
# 3556                          Android;MacOS;Windows;WordPress
# 3587              Android;Google Cloud Platform;Linux;Windows
# 3600        AWS;Docker;Google Cloud Platform;Kubernetes;Linux
# 3650        Android;AWS;Docker;Google Cloud Platform;MacOS...
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 7                                     NaN                      NaN       Yes
# 22                                    NaN                      NaN       Yes
# 58                                    NaN                      NaN       Yes
# 63                                    NaN  Straight / Heterosexual       Yes
# 149         I have little or no influence  Straight / Heterosexual       Yes
# ...                                   ...                      ...       ...
# 3332                I have some influence                      NaN       Yes
# 3556                                  NaN  Straight / Heterosexual       Yes
# 3587                                  NaN  Straight / Heterosexual       Yes
# 3600                I have some influence  Straight / Heterosexual       Yes
# 3650                I have some influence  Straight / Heterosexual       Yes
#
#                      SOComm                           SOPartFreq  \
# Respondent
# 7           Yes, definitely               Multiple times per day
# 22          Yes, definitely               Multiple times per day
# 58          Yes, definitely                                  NaN
# 63                  Neutral                 A few times per week
# 149           Yes, somewhat      A few times per month or weekly
# ...                     ...                                  ...
# 3332        Yes, definitely                Daily or almost daily
# 3556        Yes, definitely  Less than once per month or monthly
# 3587          Yes, somewhat  Less than once per month or monthly
# 3600        Yes, definitely                 A few times per week
# 3650        Yes, definitely                Daily or almost daily
#
#                        SOVisitFreq                  SurveyEase  \
# Respondent
# 7           Multiple times per day                         NaN
# 22          Multiple times per day                        Easy
# 58          Multiple times per day  Neither easy nor difficult
# 63           Daily or almost daily                        Easy
# 149         Multiple times per day  Neither easy nor difficult
# ...                            ...                         ...
# 3332         Daily or almost daily  Neither easy nor difficult
# 3556         Daily or almost daily                        Easy
# 3587          A few times per week  Neither easy nor difficult
# 3600         Daily or almost daily                        Easy
# 3650         Daily or almost daily                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 7                             NaN   NaN
# 22          Appropriate in length   NaN
# 58                       Too long   NaN
# 63          Appropriate in length    No
# 149         Appropriate in length    No
# ...                           ...   ...
# 3332        Appropriate in length   NaN
# 3556        Appropriate in length    No
# 3587                     Too long    No
# 3600        Appropriate in length    No
# 3650                     Too long    No
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 22          Computer science, computer engineering, or sof...
# 58                              Web development or web design
# 63                                                        NaN
# 149         Computer science, computer engineering, or sof...
# ...                                                       ...
# 3332        Computer science, computer engineering, or sof...
# 3556        Computer science, computer engineering, or sof...
# 3587                                                      NaN
# 3600        Computer science, computer engineering, or sof...
# 3650        Computer science, computer engineering, or sof...
#
#                                     WebframeDesireNextYear  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                 Angular.js;Django;jQuery;Laravel;Vue.js
# 149                                                    NaN
# ...                                                    ...
# 3332                                   Django;Flask;Spring
# 3556            Angular;Angular.js;Express;React.js;Spring
# 3587              Angular;Angular.js;Django;Flask;React.js
# 3600                                     Angular.js;Django
# 3650                                 Django;Flask;React.js
#
#                                         WebframeWorkedWith  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                                                     NaN
# 149                                                    NaN
# ...                                                    ...
# 3332                                          Flask;Spring
# 3556                              Angular;Express;React.js
# 3587                                                jQuery
# 3600                  Angular;Django;Express;jQuery;Spring
# 3650                               Express;React.js;Spring
#
#                                                 WelcomeChange  WorkWeekHrs  \
# Respondent
# 7                       A lot more welcome now than last year          NaN
# 22                    Just as welcome now as I felt last year         50.0
# 58                                                        NaN          NaN
# 63          Not applicable - I did not use Stack Overflow ...          NaN
# 149                  Somewhat more welcome now than last year         70.0
# ...                                                       ...          ...
# 3332                 Somewhat less welcome now than last year         35.0
# 3556                  Just as welcome now as I felt last year         50.0
# 3587                  Just as welcome now as I felt last year          NaN
# 3600        Not applicable - I did not use Stack Overflow ...         50.0
# 3650                  Just as welcome now as I felt last year         50.0
#
#            YearsCode YearsCodePro
# Respondent
# 7                  6            4
# 22                10            2
# 58               NaN          NaN
# 63                 4          NaN
# 149                5            3
# ...              ...          ...
# 3332               7            3
# 3556              22           17
# 3587               4          NaN
# 3600              17           13
# 3650               7            4
#
# [125 rows x 60 columns]

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 64859.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      103381.894515
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 48

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-cda55dd00399> in <module>()
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                               0
# Albania                                   1
# Algeria                                   3
# Andorra                                   0
# Antigua and Barbuda                       0
#                                        ...
# United States                           915
# Uruguay                                   2
# Uzbekistan                                0
# Venezuela, Bolivarian Republic of...      2
# Viet Nam                                  2
# Name: LanguageWorkedWith, Length: 104, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States         1889
# Canada                 342
# United Kingdom         190
# Germany                152
# India                  125
#                       ...
# Ethiopia                 1
# Honduras                 1
# Kyrgyzstan               1
# Panama                   1
# Hong Kong (S.A.R.)       1
# Name: Country, Length: 104, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                               0
# Albania                                   1
# Algeria                                   3
# Andorra                                   0
# Antigua and Barbuda                       0
#                                        ...
# United States                           915
# Uruguay                                   2
# Uzbekistan                                0
# Venezuela, Bolivarian Republic of...      2
# Viet Nam                                  2
# Name: LanguageWorkedWith, Length: 104, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                     Country  LanguageWorkedWith
# United States          1889                 915
# Canada                  342                 146
# United Kingdom          190                  84
# Germany                 152                  69
# India                   125                  48
# ...                     ...                 ...
# Ethiopia                  1                   0
# Honduras                  1                   1
# Kyrgyzstan                1                   0
# Panama                    1                   0
# Hong Kong (S.A.R.)        1                   1
#
# [104 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                     NumRespondents  NumKnowsPython
# United States                 1889             915
# Canada                         342             146
# United Kingdom                 190              84
# Germany                        152              69
# India                          125              48
# ...                            ...             ...
# Ethiopia                         1               0
# Honduras                         1               1
# Kyrgyzstan                       1               0
# Panama                           1               0
# Hong Kong (S.A.R.)               1               1
#
# [104 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                     NumRespondents  NumKnowsPython  PctKnowsPython
# United States                 1889             915       48.438327
# Canada                         342             146       42.690058
# United Kingdom                 190              84       44.210526
# Germany                        152              69       45.394737
# India                          125              48       38.400000
# ...                            ...             ...             ...
# Ethiopia                         1               0        0.000000
# Honduras                         1               1      100.000000
# Kyrgyzstan                       1               0        0.000000
# Panama                           1               0        0.000000
# Hong Kong (S.A.R.)               1               1      100.000000
#
# [104 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Hong Kong (S.A.R.)                                 1               1
# Luxembourg                                         1               1
# Republic of Moldova                                2               2
# Algeria                                            3               3
# Viet Nam                                           2               2
# Uganda                                             2               2
# United Republic of Tanzania                        1               1
# Syrian Arab Republic                               1               1
# Honduras                                           1               1
# China                                              3               3
# Estonia                                            4               3
# Sri Lanka                                          4               3
# United Arab Emirates                               3               2
# Venezuela, Bolivarian Republic of...               3               2
# Serbia                                             9               6
# Guatemala                                          3               2
# Armenia                                            3               2
# Nigeria                                            5               3
# Finland                                           23              13
# Chile                                              9               5
# Russian Federation                                33              17
# Kuwait                                             2               1
# Albania                                            2               1
# Nomadic                                            4               2
# Indonesia                                          2               1
# Costa Rica                                         4               2
# Taiwan                                             2               1
# Ecuador                                            4               2
# Bosnia and Herzegovina                             2               1
# Dominican Republic                                 2               1
# Uruguay                                            4               2
# Czech Republic                                    16               8
# United States                                   1889             915
# Hungary                                           11               5
# Germany                                          152              69
# France                                            60              27
# United Kingdom                                   190              84
# New Zealand                                        7               3
# Slovenia                                           7               3
# Australia                                          7               3
# Canada                                           342             146
# Israel                                            26              11
# Brazil                                            89              37
# Netherlands                                       46              19
# Romania                                           17               7
# Switzerland                                       17               7
# Georgia                                            5               2
# Poland                                            51              20
# Argentina                                         23               9
# Ukraine                                           23               9
#
#                                       PctKnowsPython
# Hong Kong (S.A.R.)                        100.000000
# Luxembourg                                100.000000
# Republic of Moldova                       100.000000
# Algeria                                   100.000000
# Viet Nam                                  100.000000
# Uganda                                    100.000000
# United Republic of Tanzania               100.000000
# Syrian Arab Republic                      100.000000
# Honduras                                  100.000000
# China                                     100.000000
# Estonia                                    75.000000
# Sri Lanka                                  75.000000
# United Arab Emirates                       66.666667
# Venezuela, Bolivarian Republic of...       66.666667
# Serbia                                     66.666667
# Guatemala                                  66.666667
# Armenia                                    66.666667
# Nigeria                                    60.000000
# Finland                                    56.521739
# Chile                                      55.555556
# Russian Federation                         51.515152
# Kuwait                                     50.000000
# Albania                                    50.000000
# Nomadic                                    50.000000
# Indonesia                                  50.000000
# Costa Rica                                 50.000000
# Taiwan                                     50.000000
# Ecuador                                    50.000000
# Bosnia and Herzegovina                     50.000000
# Dominican Republic                         50.000000
# Uruguay                                    50.000000
# Czech Republic                             50.000000
# United States                              48.438327
# Hungary                                    45.454545
# Germany                                    45.394737
# France                                     45.000000
# United Kingdom                             44.210526
# New Zealand                                42.857143
# Slovenia                                   42.857143
# Australia                                  42.857143
# Canada                                     42.690058
# Israel                                     42.307692
# Brazil                                     41.573034
# Netherlands                                41.304348
# Romania                                    41.176471
# Switzerland                                41.176471
# Georgia                                    40.000000
# Poland                                     39.215686
# Argentina                                  39.130435
# Ukraine                                    39.130435
