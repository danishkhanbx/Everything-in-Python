# %% [markdown]
# Creating using:
# *   excel File
# *   csv File
# *   Dictionary
# *   List of tuples

# %%
import pandas as pd

# %% [markdown]
# # Load Data Frame from excel file

# %%
d = pd.read_excel("/content/Marksheet.xlsx")
d
# Out:
#     Unnamed: 0         Unnamed: 1    Unnamed: 2  Unnamed: 3 Unnamed: 4
# 0          NaN                NaN           NaN         NaN        NaN
# 1          NaN                NaN  Exam Results         NaN        NaN
# 2          NaN                NaN           NaN         NaN        NaN
# 3          NaN                NaN           NaN         NaN        NaN
# 4          NaN       Student Name     Exam Name        Date     Points
# 5          NaN       James Walker       Biology  05/06/2016         31
# 6          NaN      Velma Clemons       Biology  05/06/2016         43
# 7          NaN     Kibo Underwood       Biology  05/06/2016         81
# 8          NaN        Louis Mcgee       Biology  05/06/2016         11
# 9          NaN       Phyllis Paul       Biology  05/06/2016         18
# 10         NaN     Zenaida Decker       Biology  05/06/2016         55
# 11         NaN    Gillian Tillman       Biology  05/06/2016         38
# ...

# %%
df = pd.DataFrame(d)
df
# Out:
#     Unnamed: 0         Unnamed: 1    Unnamed: 2  Unnamed: 3 Unnamed: 4
# 0          NaN                NaN           NaN         NaN        NaN
# 1          NaN                NaN  Exam Results         NaN        NaN
# 2          NaN                NaN           NaN         NaN        NaN
# 3          NaN                NaN           NaN         NaN        NaN
# 4          NaN       Student Name     Exam Name        Date     Points
# 5          NaN       James Walker       Biology  05/06/2016         31
# 6          NaN      Velma Clemons       Biology  05/06/2016         43
# 7          NaN     Kibo Underwood       Biology  05/06/2016         81
# 8          NaN        Louis Mcgee       Biology  05/06/2016         11
# 9          NaN       Phyllis Paul       Biology  05/06/2016         18
# 10         NaN     Zenaida Decker       Biology  05/06/2016         55
# 11         NaN    Gillian Tillman       Biology  05/06/2016         38
# ...

# %% [markdown]
# # Load Data Frame from csv file

# %%
data = pd.read_csv('/content/survey_results_public.csv')
data
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1                     I am a developer by profession      Yes
# 1              2                     I am a developer by profession       No
# 2              3                        I code primarily as a hobby      Yes
# 3              4                     I am a developer by profession      Yes
# 4              5  I used to be a developer by profession, but no...      Yes
# ...          ...                                                ...      ...
# 4313        4329                     I am a developer by profession      Yes
# 4314        4330                     I am a developer by profession      Yes
# 4315        4331                     I am a developer by profession      Yes
# 4316        4332             I am a student who is learning to code      Yes
# 4317        4333                     I am a developer by profession      Yes
#
# ...

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1                     I am a developer by profession      Yes
# 1              2                     I am a developer by profession       No
# 2              3                        I code primarily as a hobby      Yes
# 3              4                     I am a developer by profession      Yes
# 4              5  I used to be a developer by profession, but no...      Yes
# ...          ...                                                ...      ...
# 4313        4329                     I am a developer by profession      Yes
# 4314        4330                     I am a developer by profession      Yes
# 4315        4331                     I am a developer by profession      Yes
# 4316        4332             I am a student who is learning to code      Yes
# 4317        4333                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# # Create Data Frame using Dictionary

# %%
dic = {'Name':['Raj','Ram','Sam'], 'Roll':[1,2,3], 'English':[44,78,34], 'Maths':[99,87,56]}

# %%
df2 = pd.DataFrame(dic)
df2
# Out:
#   Name  Roll  English  Maths
# 0  Raj     1       44     99
# 1  Ram     2       78     87
# 2  Sam     3       34     56

# %% [markdown]
# # Create Data Frame using List of tuples

# %%
dt = [('a', 10), ('b', 20), ('c', 30)]

# %%
df3 = pd.DataFrame(dt)
df3
# Out:
#    0   1
# 0  a  10
# 1  b  20
# 2  c  30
